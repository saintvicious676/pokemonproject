# %%
import psycopg2
import pandas as pd
# PostgreSQL connection settings
DB_NAME = "pokemon_db"
DB_USER = "postgres"  
DB_PASSWORD = "kego"  
DB_HOST = "localhost"
DB_PORT = "5432"  

def connect_db():
    """Connects to PostgreSQL and returns a connection object."""
    return psycopg2.connect(
        dbname=DB_NAME, user=DB_USER, password=DB_PASSWORD, host=DB_HOST, port=DB_PORT
    )

# %%
from airflow import DAG
from airflow.operators.python import PythonOperator
import datetime
from datetime import datetime

# Correct the current time usage
current_time = datetime.now()

# Extract data from the API
def extract_pokemon():
    url = "https://pokeapi.co/api/v2/pokemon?limit=100"
    response = requests.get(url)
    return response.json()["results"]

# Transform the data into the required format
def transform_pokemon(pokemon_list):
    transformed_data = []
    for pokemon in pokemon_list:
        transformed_data.append((pokemon["name"], pokemon["url"]))
    return transformed_data

# Load the transformed data into PostgreSQL database
def load_pokemon_to_db(**context):
    conn = psycopg2.connect("dbname=pokemon_db user=your_username password=your_password")
    cursor = conn.cursor()
    # Pull data from the previous task (transform task)
    transformed_data = context['task_instance'].xcom_pull(task_ids='transform')
    for name, url in transformed_data:
        cursor.execute("INSERT INTO pokemon (name, api_url) VALUES (%s, %s) ON CONFLICT (name) DO NOTHING", (name, url))
    conn.commit()
    cursor.close()
    conn.close()

# Define the DAG with correct datetime format
dag = DAG(
    "pokemon_etl", 
    schedule_interval="@daily", 
    start_date=datetime(2024, 3, 1), 
    catchup=False
)

# Define the PythonOperator tasks
extract = PythonOperator(task_id="extract", python_callable=extract_pokemon, dag=dag)
transform = PythonOperator(task_id="transform", python_callable=transform_pokemon, provide_context=True, dag=dag)
load = PythonOperator(task_id="load", python_callable=load_pokemon_to_db, provide_context=True, dag=dag)

# Set the task dependencies (ETL flow)
extract >> transform >> load
# Out:
# C:\Users\Saint\AppData\Local\Temp\ipykernel_25468\2481182921.py:35 RemovedInAirflow3Warning: Param `schedule_interval` is deprecated and will be removed in a future release. Please use `schedule` instead.
# C:\Users\Saint\AppData\Local\Temp\ipykernel_25468\2481182921.py:44 RemovedInAirflow3Warning: provide_context is deprecated as of 2.0 and is no longer required
# C:\Users\Saint\AppData\Local\Temp\ipykernel_25468\2481182921.py:45 RemovedInAirflow3Warning: provide_context is deprecated as of 2.0 and is no longer required
# <Task(PythonOperator): load>

# %%
airflow scheduler &
airflow webserver --port 8080
# Out:
#   Cell In[10], line 1
#     airflow scheduler &
#             ^
# SyntaxError: invalid syntax

# %%
def connect_db():
    return psycopg2.connect(
        dbname=DB_NAME, user=DB_USER, password=DB_PASSWORD, host=DB_HOST, port=DB_PORT
    )

# Export Pokémon data to CSV
def export_pokemon_to_csv():
    conn = connect_db()
    query = """
        SELECT 
            p.id, p.name, p.height, p.weight, p.base_experience,
            STRING_AGG(DISTINCT t.name, ', ') AS types,
            STRING_AGG(DISTINCT a.name, ', ') AS abilities,
            STRING_AGG(DISTINCT m.name, ', ') AS moves
        FROM pokemon p
        LEFT JOIN pokemon_types pt ON p.id = pt.pokemon_id
        LEFT JOIN types t ON pt.type_id = t.id
        LEFT JOIN pokemon_abilities pa ON p.id = pa.pokemon_id
        LEFT JOIN abilities a ON pa.ability_id = a.id
        LEFT JOIN pokemon_moves pm ON p.id = pm.pokemon_id
        LEFT JOIN moves m ON pm.move_id = m.id
        GROUP BY p.id
    """
    
    df = pd.read_sql(query, conn)  # Load data into Pandas DataFrame
    conn.close()
    
    # Save to CSV
    df.to_csv("pokemon_data.csv", index=False)
    print("CSV file created: pokemon_data.csv")

# Run export function
export_pokemon_to_csv()
# Out:
# C:\Users\Saint\AppData\Local\Temp\ipykernel_25656\2779073697.py:25: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)  # Load data into Pandas DataFrame
# CSV file created: pokemon_data.csv

# %%
import networkx as nx

query = "SELECT pokemon_id, evolves_to FROM evolutions"
df = pd.read_sql(query, conn)

G = nx.DiGraph()
for _, row in df.iterrows():
    G.add_edge(row['pokemon_id'], row['evolves_to'])

plt.figure(figsize=(12, 8))
nx.draw(G, with_labels=True, node_color="lightblue", edge_color="gray", node_size=2000, font_size=10)
plt.title("Pokémon Evolution Chain")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 import networkx as nx
#       3 query = "SELECT pokemon_id, evolves_to FROM evolutions"
# ----> 4 df = pd.read_sql(query, conn)
#       6 G = nx.DiGraph()
#       7 for _, row in df.iterrows():
#
# NameError: name 'conn' is not defined

# %%
def connect_db():
    return psycopg2.connect(
        dbname=DB_NAME, user=DB_USER, password=DB_PASSWORD, host=DB_HOST, port=DB_PORT
    )

# Fetch Pokémon list
def fetch_pokemon_list(limit=100):
    url = f"https://pokeapi.co/api/v2/pokemon?limit={limit}"
    response = requests.get(url)
    if response.status_code == 200:
        return [p['name'] for p in response.json()['results']]
    return []

# Fetch Pokémon details
def fetch_pokemon_data(pokemon_name):
    url = f"https://pokeapi.co/api/v2/pokemon/{pokemon_name.lower()}"
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    return None

# Fetch evolution data
def fetch_evolution_chain(pokemon_id):
    url = f"https://pokeapi.co/api/v2/pokemon-species/{pokemon_id}"
    response = requests.get(url)
    if response.status_code == 200:
        species_data = response.json()
        if "evolution_chain" in species_data:
            chain_url = species_data["evolution_chain"]["url"]
            evolution_response = requests.get(chain_url)
            if evolution_response.status_code == 200:
                return evolution_response.json()
    return None

# Insert Pokémon data efficiently
def insert_pokemon(data):
    conn = connect_db()
    cursor = conn.cursor()

    # Insert Pokémon
    cursor.execute("""
        INSERT INTO pokemon (id, name, height, weight, base_experience)
        VALUES (%s, %s, %s, %s, %s)
        ON CONFLICT (id) DO NOTHING
    """, (data['id'], data['name'], data['height'], data['weight'], data['base_experience']))

    # Insert Types
    for type_info in data['types']:
        type_name = type_info['type']['name']
        cursor.execute("INSERT INTO types (name) VALUES (%s) ON CONFLICT (name) DO NOTHING", (type_name,))
        cursor.execute("""
            INSERT INTO pokemon_types (pokemon_id, type_id)
            SELECT %s, id FROM types WHERE name = %s
            ON CONFLICT DO NOTHING
        """, (data['id'], type_name))

    # Insert Abilities
    for ability_info in data['abilities']:
        ability_name = ability_info['ability']['name']
        cursor.execute("INSERT INTO abilities (name) VALUES (%s) ON CONFLICT (name) DO NOTHING", (ability_name,))
        cursor.execute("""
            INSERT INTO pokemon_abilities (pokemon_id, ability_id)
            SELECT %s, id FROM abilities WHERE name = %s
            ON CONFLICT DO NOTHING
        """, (data['id'], ability_name))

    # Insert Moves
    for move_info in data['moves']:
        move_name = move_info['move']['name']
        cursor.execute("INSERT INTO moves (name) VALUES (%s) ON CONFLICT (name) DO NOTHING", (move_name,))
        cursor.execute("""
            INSERT INTO pokemon_moves (pokemon_id, move_id)
            SELECT %s, id FROM moves WHERE name = %s
            ON CONFLICT DO NOTHING
        """, (data['id'], move_name))

    # Insert Stats
    for stat_info in data['stats']:
        stat_name = stat_info['stat']['name']
        base_stat = stat_info['base_stat']
        cursor.execute("INSERT INTO stats (name) VALUES (%s) ON CONFLICT (name) DO NOTHING", (stat_name,))
        cursor.execute("""
            INSERT INTO pokemon_stats (pokemon_id, stat_id, base_stat)
            SELECT %s, id, %s FROM stats WHERE name = %s
            ON CONFLICT DO NOTHING
        """, (data['id'], base_stat, stat_name))

    # Insert Evolution Data
    evolution_data = fetch_evolution_chain(data['id'])
    if evolution_data:
        chain = evolution_data["chain"]
        evolves_to = chain["evolves_to"]
        if evolves_to:
            for evolution in evolves_to:
                evolved_name = evolution["species"]["name"]
                cursor.execute("""
                    INSERT INTO evolutions (pokemon_id, evolves_to)
                    VALUES (%s, %s)
                    ON CONFLICT DO NOTHING
                """, (data['id'], evolved_name))

    conn.commit()
    cursor.close()
    conn.close()

# Bulk fetch and insert
pokemon_names = fetch_pokemon_list(limit=2000)
for name in pokemon_names:
    data = fetch_pokemon_data(name)
    if data:
        insert_pokemon(data)
        print(f"Inserted {name} into PostgreSQL database.")
# Out:
# Inserted bulbasaur into PostgreSQL database.
# Inserted ivysaur into PostgreSQL database.
# Inserted venusaur into PostgreSQL database.
# Inserted charmander into PostgreSQL database.
# Inserted charmeleon into PostgreSQL database.
# Inserted charizard into PostgreSQL database.
# Inserted squirtle into PostgreSQL database.
# Inserted wartortle into PostgreSQL database.
# Inserted blastoise into PostgreSQL database.
# Inserted caterpie into PostgreSQL database.
# Inserted metapod into PostgreSQL database.
# Inserted butterfree into PostgreSQL database.
# Inserted weedle into PostgreSQL database.
# Inserted kakuna into PostgreSQL database.
# Inserted beedrill into PostgreSQL database.
# Inserted pidgey into PostgreSQL database.
# Inserted pidgeotto into PostgreSQL database.
# Inserted pidgeot into PostgreSQL database.
# Inserted rattata into PostgreSQL database.
# Inserted raticate into PostgreSQL database.
# Inserted spearow into PostgreSQL database.
# Inserted fearow into PostgreSQL database.
# Inserted ekans into PostgreSQL database.
# Inserted arbok into PostgreSQL database.
# Inserted pikachu into PostgreSQL database.
# Inserted raichu into PostgreSQL database.
# Inserted sandshrew into PostgreSQL database.
# Inserted sandslash into PostgreSQL database.
# Inserted nidoran-f into PostgreSQL database.
# Inserted nidorina into PostgreSQL database.
# Inserted nidoqueen into PostgreSQL database.
# Inserted nidoran-m into PostgreSQL database.
# Inserted nidorino into PostgreSQL database.
# Inserted nidoking into PostgreSQL database.
# Inserted clefairy into PostgreSQL database.
# Inserted clefable into PostgreSQL database.
# Inserted vulpix into PostgreSQL database.
# Inserted ninetales into PostgreSQL database.
# Inserted jigglypuff into PostgreSQL database.
# Inserted wigglytuff into PostgreSQL database.
# Inserted zubat into PostgreSQL database.
# Inserted golbat into PostgreSQL database.
# Inserted oddish into PostgreSQL database.
# Inserted gloom into PostgreSQL database.
# Inserted vileplume into PostgreSQL database.
# Inserted paras into PostgreSQL database.
# Inserted parasect into PostgreSQL database.
# Inserted venonat into PostgreSQL database.
# Inserted venomoth into PostgreSQL database.
# Inserted diglett into PostgreSQL database.
# Inserted dugtrio into PostgreSQL database.
# Inserted meowth into PostgreSQL database.
# Inserted persian into PostgreSQL database.
# Inserted psyduck into PostgreSQL database.
# Inserted golduck into PostgreSQL database.
# Inserted mankey into PostgreSQL database.
# Inserted primeape into PostgreSQL database.
# Inserted growlithe into PostgreSQL database.
# Inserted arcanine into PostgreSQL database.
# Inserted poliwag into PostgreSQL database.
# Inserted poliwhirl into PostgreSQL database.
# Inserted poliwrath into PostgreSQL database.
# Inserted abra into PostgreSQL database.
# Inserted kadabra into PostgreSQL database.
# Inserted alakazam into PostgreSQL database.
# Inserted machop into PostgreSQL database.
# Inserted machoke into PostgreSQL database.
# Inserted machamp into PostgreSQL database.
# Inserted bellsprout into PostgreSQL database.
# Inserted weepinbell into PostgreSQL database.
# Inserted victreebel into PostgreSQL database.
# Inserted tentacool into PostgreSQL database.
# Inserted tentacruel into PostgreSQL database.
# Inserted geodude into PostgreSQL database.
# Inserted graveler into PostgreSQL database.
# Inserted golem into PostgreSQL database.
# Inserted ponyta into PostgreSQL database.
# Inserted rapidash into PostgreSQL database.
# Inserted slowpoke into PostgreSQL database.
# Inserted slowbro into PostgreSQL database.
# Inserted magnemite into PostgreSQL database.
# Inserted magneton into PostgreSQL database.
# Inserted farfetchd into PostgreSQL database.
# Inserted doduo into PostgreSQL database.
# Inserted dodrio into PostgreSQL database.
# Inserted seel into PostgreSQL database.
# Inserted dewgong into PostgreSQL database.
# Inserted grimer into PostgreSQL database.
# Inserted muk into PostgreSQL database.
# Inserted shellder into PostgreSQL database.
# Inserted cloyster into PostgreSQL database.
# Inserted gastly into PostgreSQL database.
# Inserted haunter into PostgreSQL database.
# Inserted gengar into PostgreSQL database.
# Inserted onix into PostgreSQL database.
# Inserted drowzee into PostgreSQL database.
# Inserted hypno into PostgreSQL database.
# Inserted krabby into PostgreSQL database.
# Inserted kingler into PostgreSQL database.
# Inserted voltorb into PostgreSQL database.
# Inserted electrode into PostgreSQL database.
# Inserted exeggcute into PostgreSQL database.
# Inserted exeggutor into PostgreSQL database.
# Inserted cubone into PostgreSQL database.
# Inserted marowak into PostgreSQL database.
# Inserted hitmonlee into PostgreSQL database.
# Inserted hitmonchan into PostgreSQL database.
# Inserted lickitung into PostgreSQL database.
# Inserted koffing into PostgreSQL database.
# Inserted weezing into PostgreSQL database.
# Inserted rhyhorn into PostgreSQL database.
# Inserted rhydon into PostgreSQL database.
# Inserted chansey into PostgreSQL database.
# Inserted tangela into PostgreSQL database.
# Inserted kangaskhan into PostgreSQL database.
# Inserted horsea into PostgreSQL database.
# Inserted seadra into PostgreSQL database.
# Inserted goldeen into PostgreSQL database.
# Inserted seaking into PostgreSQL database.
# Inserted staryu into PostgreSQL database.
# Inserted starmie into PostgreSQL database.
# Inserted mr-mime into PostgreSQL database.
# Inserted scyther into PostgreSQL database.
# Inserted jynx into PostgreSQL database.
# Inserted electabuzz into PostgreSQL database.
# Inserted magmar into PostgreSQL database.
# Inserted pinsir into PostgreSQL database.
# Inserted tauros into PostgreSQL database.
# Inserted magikarp into PostgreSQL database.
# Inserted gyarados into PostgreSQL database.
# Inserted lapras into PostgreSQL database.
# Inserted ditto into PostgreSQL database.
# Inserted eevee into PostgreSQL database.
# Inserted vaporeon into PostgreSQL database.
# Inserted jolteon into PostgreSQL database.
# Inserted flareon into PostgreSQL database.
# Inserted porygon into PostgreSQL database.
# Inserted omanyte into PostgreSQL database.
# Inserted omastar into PostgreSQL database.
# Inserted kabuto into PostgreSQL database.
# Inserted kabutops into PostgreSQL database.
# Inserted aerodactyl into PostgreSQL database.
# Inserted snorlax into PostgreSQL database.
# Inserted articuno into PostgreSQL database.
# Inserted zapdos into PostgreSQL database.
# Inserted moltres into PostgreSQL database.
# Inserted dratini into PostgreSQL database.
# Inserted dragonair into PostgreSQL database.
# Inserted dragonite into PostgreSQL database.
# Inserted mewtwo into PostgreSQL database.
# Inserted mew into PostgreSQL database.
# Inserted chikorita into PostgreSQL database.
# Inserted bayleef into PostgreSQL database.
# Inserted meganium into PostgreSQL database.
# Inserted cyndaquil into PostgreSQL database.
# Inserted quilava into PostgreSQL database.
# Inserted typhlosion into PostgreSQL database.
# Inserted totodile into PostgreSQL database.
# Inserted croconaw into PostgreSQL database.
# Inserted feraligatr into PostgreSQL database.
# Inserted sentret into PostgreSQL database.
# Inserted furret into PostgreSQL database.
# Inserted hoothoot into PostgreSQL database.
# Inserted noctowl into PostgreSQL database.
# Inserted ledyba into PostgreSQL database.
# Inserted ledian into PostgreSQL database.
# Inserted spinarak into PostgreSQL database.
# Inserted ariados into PostgreSQL database.
# Inserted crobat into PostgreSQL database.
# Inserted chinchou into PostgreSQL database.
# Inserted lanturn into PostgreSQL database.
# Inserted pichu into PostgreSQL database.
# Inserted cleffa into PostgreSQL database.
# Inserted igglybuff into PostgreSQL database.
# Inserted togepi into PostgreSQL database.
# Inserted togetic into PostgreSQL database.
# Inserted natu into PostgreSQL database.
# Inserted xatu into PostgreSQL database.
# Inserted mareep into PostgreSQL database.
# Inserted flaaffy into PostgreSQL database.
# Inserted ampharos into PostgreSQL database.
# Inserted bellossom into PostgreSQL database.
# Inserted marill into PostgreSQL database.
# Inserted azumarill into PostgreSQL database.
# Inserted sudowoodo into PostgreSQL database.
# Inserted politoed into PostgreSQL database.
# Inserted hoppip into PostgreSQL database.
# Inserted skiploom into PostgreSQL database.
# Inserted jumpluff into PostgreSQL database.
# Inserted aipom into PostgreSQL database.
# Inserted sunkern into PostgreSQL database.
# Inserted sunflora into PostgreSQL database.
# Inserted yanma into PostgreSQL database.
# Inserted wooper into PostgreSQL database.
# Inserted quagsire into PostgreSQL database.
# Inserted espeon into PostgreSQL database.
# Inserted umbreon into PostgreSQL database.
# Inserted murkrow into PostgreSQL database.
# Inserted slowking into PostgreSQL database.
# Inserted misdreavus into PostgreSQL database.
# Inserted unown into PostgreSQL database.
# Inserted wobbuffet into PostgreSQL database.
# Inserted girafarig into PostgreSQL database.
# Inserted pineco into PostgreSQL database.
# Inserted forretress into PostgreSQL database.
# Inserted dunsparce into PostgreSQL database.
# Inserted gligar into PostgreSQL database.
# Inserted steelix into PostgreSQL database.
# Inserted snubbull into PostgreSQL database.
# Inserted granbull into PostgreSQL database.
# Inserted qwilfish into PostgreSQL database.
# Inserted scizor into PostgreSQL database.
# Inserted shuckle into PostgreSQL database.
# Inserted heracross into PostgreSQL database.
# Inserted sneasel into PostgreSQL database.
# Inserted teddiursa into PostgreSQL database.
# Inserted ursaring into PostgreSQL database.
# Inserted slugma into PostgreSQL database.
# Inserted magcargo into PostgreSQL database.
# Inserted swinub into PostgreSQL database.
# Inserted piloswine into PostgreSQL database.
# Inserted corsola into PostgreSQL database.
# Inserted remoraid into PostgreSQL database.
# Inserted octillery into PostgreSQL database.
# Inserted delibird into PostgreSQL database.
# Inserted mantine into PostgreSQL database.
# Inserted skarmory into PostgreSQL database.
# Inserted houndour into PostgreSQL database.
# Inserted houndoom into PostgreSQL database.
# Inserted kingdra into PostgreSQL database.
# Inserted phanpy into PostgreSQL database.
# Inserted donphan into PostgreSQL database.
# Inserted porygon2 into PostgreSQL database.
# Inserted stantler into PostgreSQL database.
# Inserted smeargle into PostgreSQL database.
# Inserted tyrogue into PostgreSQL database.
# Inserted hitmontop into PostgreSQL database.
# Inserted smoochum into PostgreSQL database.
# Inserted elekid into PostgreSQL database.
# Inserted magby into PostgreSQL database.
# Inserted miltank into PostgreSQL database.
# Inserted blissey into PostgreSQL database.
# Inserted raikou into PostgreSQL database.
# Inserted entei into PostgreSQL database.
# Inserted suicune into PostgreSQL database.
# Inserted larvitar into PostgreSQL database.
# Inserted pupitar into PostgreSQL database.
# Inserted tyranitar into PostgreSQL database.
# Inserted lugia into PostgreSQL database.
# Inserted ho-oh into PostgreSQL database.
# Inserted celebi into PostgreSQL database.
# Inserted treecko into PostgreSQL database.
# Inserted grovyle into PostgreSQL database.
# Inserted sceptile into PostgreSQL database.
# Inserted torchic into PostgreSQL database.
# Inserted combusken into PostgreSQL database.
# Inserted blaziken into PostgreSQL database.
# Inserted mudkip into PostgreSQL database.
# Inserted marshtomp into PostgreSQL database.
# Inserted swampert into PostgreSQL database.
# Inserted poochyena into PostgreSQL database.
# Inserted mightyena into PostgreSQL database.
# Inserted zigzagoon into PostgreSQL database.
# Inserted linoone into PostgreSQL database.
# Inserted wurmple into PostgreSQL database.
# Inserted silcoon into PostgreSQL database.
# Inserted beautifly into PostgreSQL database.
# Inserted cascoon into PostgreSQL database.
# Inserted dustox into PostgreSQL database.
# Inserted lotad into PostgreSQL database.
# Inserted lombre into PostgreSQL database.
# Inserted ludicolo into PostgreSQL database.
# Inserted seedot into PostgreSQL database.
# Inserted nuzleaf into PostgreSQL database.
# Inserted shiftry into PostgreSQL database.
# Inserted taillow into PostgreSQL database.
# Inserted swellow into PostgreSQL database.
# Inserted wingull into PostgreSQL database.
# Inserted pelipper into PostgreSQL database.
# Inserted ralts into PostgreSQL database.
# Inserted kirlia into PostgreSQL database.
# Inserted gardevoir into PostgreSQL database.
# Inserted surskit into PostgreSQL database.
# Inserted masquerain into PostgreSQL database.
# Inserted shroomish into PostgreSQL database.
# Inserted breloom into PostgreSQL database.
# Inserted slakoth into PostgreSQL database.
# Inserted vigoroth into PostgreSQL database.
# Inserted slaking into PostgreSQL database.
# Inserted nincada into PostgreSQL database.
# Inserted ninjask into PostgreSQL database.
# Inserted shedinja into PostgreSQL database.
# Inserted whismur into PostgreSQL database.
# Inserted loudred into PostgreSQL database.
# Inserted exploud into PostgreSQL database.
# Inserted makuhita into PostgreSQL database.
# Inserted hariyama into PostgreSQL database.
# Inserted azurill into PostgreSQL database.
# Inserted nosepass into PostgreSQL database.
# Inserted skitty into PostgreSQL database.
# Inserted delcatty into PostgreSQL database.
# Inserted sableye into PostgreSQL database.
# Inserted mawile into PostgreSQL database.
# Inserted aron into PostgreSQL database.
# Inserted lairon into PostgreSQL database.
# Inserted aggron into PostgreSQL database.
# Inserted meditite into PostgreSQL database.
# Inserted medicham into PostgreSQL database.
# Inserted electrike into PostgreSQL database.
# Inserted manectric into PostgreSQL database.
# Inserted plusle into PostgreSQL database.
# Inserted minun into PostgreSQL database.
# Inserted volbeat into PostgreSQL database.
# Inserted illumise into PostgreSQL database.
# Inserted roselia into PostgreSQL database.
# Inserted gulpin into PostgreSQL database.
# Inserted swalot into PostgreSQL database.
# Inserted carvanha into PostgreSQL database.
# Inserted sharpedo into PostgreSQL database.
# Inserted wailmer into PostgreSQL database.
# Inserted wailord into PostgreSQL database.
# Inserted numel into PostgreSQL database.
# Inserted camerupt into PostgreSQL database.
# Inserted torkoal into PostgreSQL database.
# Inserted spoink into PostgreSQL database.
# Inserted grumpig into PostgreSQL database.
# Inserted spinda into PostgreSQL database.
# Inserted trapinch into PostgreSQL database.
# Inserted vibrava into PostgreSQL database.
# Inserted flygon into PostgreSQL database.
# Inserted cacnea into PostgreSQL database.
# Inserted cacturne into PostgreSQL database.
# Inserted swablu into PostgreSQL database.
# Inserted altaria into PostgreSQL database.
# Inserted zangoose into PostgreSQL database.
# Inserted seviper into PostgreSQL database.
# Inserted lunatone into PostgreSQL database.
# Inserted solrock into PostgreSQL database.
# Inserted barboach into PostgreSQL database.
# Inserted whiscash into PostgreSQL database.
# Inserted corphish into PostgreSQL database.
# Inserted crawdaunt into PostgreSQL database.
# Inserted baltoy into PostgreSQL database.
# Inserted claydol into PostgreSQL database.
# Inserted lileep into PostgreSQL database.
# Inserted cradily into PostgreSQL database.
# Inserted anorith into PostgreSQL database.
# Inserted armaldo into PostgreSQL database.
# Inserted feebas into PostgreSQL database.
# Inserted milotic into PostgreSQL database.
# Inserted castform into PostgreSQL database.
# Inserted kecleon into PostgreSQL database.
# Inserted shuppet into PostgreSQL database.
# Inserted banette into PostgreSQL database.
# Inserted duskull into PostgreSQL database.
# Inserted dusclops into PostgreSQL database.
# Inserted tropius into PostgreSQL database.
# Inserted chimecho into PostgreSQL database.
# Inserted absol into PostgreSQL database.
# Inserted wynaut into PostgreSQL database.
# Inserted snorunt into PostgreSQL database.
# Inserted glalie into PostgreSQL database.
# Inserted spheal into PostgreSQL database.
# Inserted sealeo into PostgreSQL database.
# Inserted walrein into PostgreSQL database.
# Inserted clamperl into PostgreSQL database.
# Inserted huntail into PostgreSQL database.
# Inserted gorebyss into PostgreSQL database.
# Inserted relicanth into PostgreSQL database.
# Inserted luvdisc into PostgreSQL database.
# Inserted bagon into PostgreSQL database.
# Inserted shelgon into PostgreSQL database.
# Inserted salamence into PostgreSQL database.
# Inserted beldum into PostgreSQL database.
# Inserted metang into PostgreSQL database.
# Inserted metagross into PostgreSQL database.
# Inserted regirock into PostgreSQL database.
# Inserted regice into PostgreSQL database.
# Inserted registeel into PostgreSQL database.
# Inserted latias into PostgreSQL database.
# Inserted latios into PostgreSQL database.
# Inserted kyogre into PostgreSQL database.
# Inserted groudon into PostgreSQL database.
# Inserted rayquaza into PostgreSQL database.
# Inserted jirachi into PostgreSQL database.
# Inserted deoxys-normal into PostgreSQL database.
# Inserted turtwig into PostgreSQL database.
# Inserted grotle into PostgreSQL database.
# Inserted torterra into PostgreSQL database.
# Inserted chimchar into PostgreSQL database.
# Inserted monferno into PostgreSQL database.
# Inserted infernape into PostgreSQL database.
# Inserted piplup into PostgreSQL database.
# Inserted prinplup into PostgreSQL database.
# Inserted empoleon into PostgreSQL database.
# Inserted starly into PostgreSQL database.
# Inserted staravia into PostgreSQL database.
# Inserted staraptor into PostgreSQL database.
# Inserted bidoof into PostgreSQL database.
# Inserted bibarel into PostgreSQL database.
# Inserted kricketot into PostgreSQL database.
# Inserted kricketune into PostgreSQL database.
# Inserted shinx into PostgreSQL database.
# Inserted luxio into PostgreSQL database.
# Inserted luxray into PostgreSQL database.
# Inserted budew into PostgreSQL database.
# Inserted roserade into PostgreSQL database.
# Inserted cranidos into PostgreSQL database.
# Inserted rampardos into PostgreSQL database.
# Inserted shieldon into PostgreSQL database.
# Inserted bastiodon into PostgreSQL database.
# Inserted burmy into PostgreSQL database.
# Inserted wormadam-plant into PostgreSQL database.
# Inserted mothim into PostgreSQL database.
# Inserted combee into PostgreSQL database.
# Inserted vespiquen into PostgreSQL database.
# Inserted pachirisu into PostgreSQL database.
# Inserted buizel into PostgreSQL database.
# Inserted floatzel into PostgreSQL database.
# Inserted cherubi into PostgreSQL database.
# Inserted cherrim into PostgreSQL database.
# Inserted shellos into PostgreSQL database.
# Inserted gastrodon into PostgreSQL database.
# Inserted ambipom into PostgreSQL database.
# Inserted drifloon into PostgreSQL database.
# Inserted drifblim into PostgreSQL database.
# Inserted buneary into PostgreSQL database.
# Inserted lopunny into PostgreSQL database.
# Inserted mismagius into PostgreSQL database.
# Inserted honchkrow into PostgreSQL database.
# Inserted glameow into PostgreSQL database.
# Inserted purugly into PostgreSQL database.
# Inserted chingling into PostgreSQL database.
# Inserted stunky into PostgreSQL database.
# Inserted skuntank into PostgreSQL database.
# Inserted bronzor into PostgreSQL database.
# Inserted bronzong into PostgreSQL database.
# Inserted bonsly into PostgreSQL database.
# Inserted mime-jr into PostgreSQL database.
# Inserted happiny into PostgreSQL database.
# Inserted chatot into PostgreSQL database.
# Inserted spiritomb into PostgreSQL database.
# Inserted gible into PostgreSQL database.
# Inserted gabite into PostgreSQL database.
# Inserted garchomp into PostgreSQL database.
# Inserted munchlax into PostgreSQL database.
# Inserted riolu into PostgreSQL database.
# Inserted lucario into PostgreSQL database.
# Inserted hippopotas into PostgreSQL database.
# Inserted hippowdon into PostgreSQL database.
# Inserted skorupi into PostgreSQL database.
# Inserted drapion into PostgreSQL database.
# Inserted croagunk into PostgreSQL database.
# Inserted toxicroak into PostgreSQL database.
# Inserted carnivine into PostgreSQL database.
# Inserted finneon into PostgreSQL database.
# Inserted lumineon into PostgreSQL database.
# Inserted mantyke into PostgreSQL database.
# Inserted snover into PostgreSQL database.
# Inserted abomasnow into PostgreSQL database.
# Inserted weavile into PostgreSQL database.
# Inserted magnezone into PostgreSQL database.
# Inserted lickilicky into PostgreSQL database.
# Inserted rhyperior into PostgreSQL database.
# Inserted tangrowth into PostgreSQL database.
# Inserted electivire into PostgreSQL database.
# Inserted magmortar into PostgreSQL database.
# Inserted togekiss into PostgreSQL database.
# Inserted yanmega into PostgreSQL database.
# Inserted leafeon into PostgreSQL database.
# Inserted glaceon into PostgreSQL database.
# Inserted gliscor into PostgreSQL database.
# Inserted mamoswine into PostgreSQL database.
# Inserted porygon-z into PostgreSQL database.
# Inserted gallade into PostgreSQL database.
# Inserted probopass into PostgreSQL database.
# Inserted dusknoir into PostgreSQL database.
# Inserted froslass into PostgreSQL database.
# Inserted rotom into PostgreSQL database.
# Inserted uxie into PostgreSQL database.
# Inserted mesprit into PostgreSQL database.
# Inserted azelf into PostgreSQL database.
# Inserted dialga into PostgreSQL database.
# Inserted palkia into PostgreSQL database.
# Inserted heatran into PostgreSQL database.
# Inserted regigigas into PostgreSQL database.
# Inserted giratina-altered into PostgreSQL database.
# Inserted cresselia into PostgreSQL database.
# Inserted phione into PostgreSQL database.
# Inserted manaphy into PostgreSQL database.
# Inserted darkrai into PostgreSQL database.
# Inserted shaymin-land into PostgreSQL database.
# Inserted arceus into PostgreSQL database.
# Inserted victini into PostgreSQL database.
# Inserted snivy into PostgreSQL database.
# Inserted servine into PostgreSQL database.
# Inserted serperior into PostgreSQL database.
# Inserted tepig into PostgreSQL database.
# Inserted pignite into PostgreSQL database.
# Inserted emboar into PostgreSQL database.
# Inserted oshawott into PostgreSQL database.
# Inserted dewott into PostgreSQL database.
# Inserted samurott into PostgreSQL database.
# Inserted patrat into PostgreSQL database.
# Inserted watchog into PostgreSQL database.
# Inserted lillipup into PostgreSQL database.
# Inserted herdier into PostgreSQL database.
# Inserted stoutland into PostgreSQL database.
# Inserted purrloin into PostgreSQL database.
# Inserted liepard into PostgreSQL database.
# Inserted pansage into PostgreSQL database.
# Inserted simisage into PostgreSQL database.
# Inserted pansear into PostgreSQL database.
# Inserted simisear into PostgreSQL database.
# Inserted panpour into PostgreSQL database.
# Inserted simipour into PostgreSQL database.
# Inserted munna into PostgreSQL database.
# Inserted musharna into PostgreSQL database.
# Inserted pidove into PostgreSQL database.
# Inserted tranquill into PostgreSQL database.
# Inserted unfezant into PostgreSQL database.
# Inserted blitzle into PostgreSQL database.
# Inserted zebstrika into PostgreSQL database.
# Inserted roggenrola into PostgreSQL database.
# Inserted boldore into PostgreSQL database.
# Inserted gigalith into PostgreSQL database.
# Inserted woobat into PostgreSQL database.
# Inserted swoobat into PostgreSQL database.
# Inserted drilbur into PostgreSQL database.
# Inserted excadrill into PostgreSQL database.
# Inserted audino into PostgreSQL database.
# Inserted timburr into PostgreSQL database.
# Inserted gurdurr into PostgreSQL database.
# Inserted conkeldurr into PostgreSQL database.
# Inserted tympole into PostgreSQL database.
# Inserted palpitoad into PostgreSQL database.
# Inserted seismitoad into PostgreSQL database.
# Inserted throh into PostgreSQL database.
# Inserted sawk into PostgreSQL database.
# Inserted sewaddle into PostgreSQL database.
# Inserted swadloon into PostgreSQL database.
# Inserted leavanny into PostgreSQL database.
# Inserted venipede into PostgreSQL database.
# Inserted whirlipede into PostgreSQL database.
# Inserted scolipede into PostgreSQL database.
# Inserted cottonee into PostgreSQL database.
# Inserted whimsicott into PostgreSQL database.
# Inserted petilil into PostgreSQL database.
# Inserted lilligant into PostgreSQL database.
# Inserted basculin-red-striped into PostgreSQL database.
# Inserted sandile into PostgreSQL database.
# Inserted krokorok into PostgreSQL database.
# Inserted krookodile into PostgreSQL database.
# Inserted darumaka into PostgreSQL database.
# Inserted darmanitan-standard into PostgreSQL database.
# Inserted maractus into PostgreSQL database.
# Inserted dwebble into PostgreSQL database.
# Inserted crustle into PostgreSQL database.
# Inserted scraggy into PostgreSQL database.
# Inserted scrafty into PostgreSQL database.
# Inserted sigilyph into PostgreSQL database.
# Inserted yamask into PostgreSQL database.
# Inserted cofagrigus into PostgreSQL database.
# Inserted tirtouga into PostgreSQL database.
# Inserted carracosta into PostgreSQL database.
# Inserted archen into PostgreSQL database.
# Inserted archeops into PostgreSQL database.
# Inserted trubbish into PostgreSQL database.
# Inserted garbodor into PostgreSQL database.
# Inserted zorua into PostgreSQL database.
# Inserted zoroark into PostgreSQL database.
# Inserted minccino into PostgreSQL database.
# Inserted cinccino into PostgreSQL database.
# Inserted gothita into PostgreSQL database.
# Inserted gothorita into PostgreSQL database.
# Inserted gothitelle into PostgreSQL database.
# Inserted solosis into PostgreSQL database.
# Inserted duosion into PostgreSQL database.
# Inserted reuniclus into PostgreSQL database.
# Inserted ducklett into PostgreSQL database.
# Inserted swanna into PostgreSQL database.
# Inserted vanillite into PostgreSQL database.
# Inserted vanillish into PostgreSQL database.
# Inserted vanilluxe into PostgreSQL database.
# Inserted deerling into PostgreSQL database.
# Inserted sawsbuck into PostgreSQL database.
# Inserted emolga into PostgreSQL database.
# Inserted karrablast into PostgreSQL database.
# Inserted escavalier into PostgreSQL database.
# Inserted foongus into PostgreSQL database.
# Inserted amoonguss into PostgreSQL database.
# Inserted frillish into PostgreSQL database.
# Inserted jellicent into PostgreSQL database.
# Inserted alomomola into PostgreSQL database.
# Inserted joltik into PostgreSQL database.
# Inserted galvantula into PostgreSQL database.
# Inserted ferroseed into PostgreSQL database.
# Inserted ferrothorn into PostgreSQL database.
# Inserted klink into PostgreSQL database.
# Inserted klang into PostgreSQL database.
# Inserted klinklang into PostgreSQL database.
# Inserted tynamo into PostgreSQL database.
# Inserted eelektrik into PostgreSQL database.
# Inserted eelektross into PostgreSQL database.
# Inserted elgyem into PostgreSQL database.
# Inserted beheeyem into PostgreSQL database.
# Inserted litwick into PostgreSQL database.
# Inserted lampent into PostgreSQL database.
# Inserted chandelure into PostgreSQL database.
# Inserted axew into PostgreSQL database.
# Inserted fraxure into PostgreSQL database.
# Inserted haxorus into PostgreSQL database.
# Inserted cubchoo into PostgreSQL database.
# Inserted beartic into PostgreSQL database.
# Inserted cryogonal into PostgreSQL database.
# Inserted shelmet into PostgreSQL database.
# Inserted accelgor into PostgreSQL database.
# Inserted stunfisk into PostgreSQL database.
# Inserted mienfoo into PostgreSQL database.
# Inserted mienshao into PostgreSQL database.
# Inserted druddigon into PostgreSQL database.
# Inserted golett into PostgreSQL database.
# Inserted golurk into PostgreSQL database.
# Inserted pawniard into PostgreSQL database.
# Inserted bisharp into PostgreSQL database.
# Inserted bouffalant into PostgreSQL database.
# Inserted rufflet into PostgreSQL database.
# Inserted braviary into PostgreSQL database.
# Inserted vullaby into PostgreSQL database.
# Inserted mandibuzz into PostgreSQL database.
# Inserted heatmor into PostgreSQL database.
# Inserted durant into PostgreSQL database.
# Inserted deino into PostgreSQL database.
# Inserted zweilous into PostgreSQL database.
# Inserted hydreigon into PostgreSQL database.
# Inserted larvesta into PostgreSQL database.
# Inserted volcarona into PostgreSQL database.
# Inserted cobalion into PostgreSQL database.
# Inserted terrakion into PostgreSQL database.
# Inserted virizion into PostgreSQL database.
# Inserted tornadus-incarnate into PostgreSQL database.
# Inserted thundurus-incarnate into PostgreSQL database.
# Inserted reshiram into PostgreSQL database.
# Inserted zekrom into PostgreSQL database.
# Inserted landorus-incarnate into PostgreSQL database.
# Inserted kyurem into PostgreSQL database.
# Inserted keldeo-ordinary into PostgreSQL database.
# Inserted meloetta-aria into PostgreSQL database.
# Inserted genesect into PostgreSQL database.
# Inserted chespin into PostgreSQL database.
# Inserted quilladin into PostgreSQL database.
# Inserted chesnaught into PostgreSQL database.
# Inserted fennekin into PostgreSQL database.
# Inserted braixen into PostgreSQL database.
# Inserted delphox into PostgreSQL database.
# Inserted froakie into PostgreSQL database.
# Inserted frogadier into PostgreSQL database.
# Inserted greninja into PostgreSQL database.
# Inserted bunnelby into PostgreSQL database.
# Inserted diggersby into PostgreSQL database.
# Inserted fletchling into PostgreSQL database.
# Inserted fletchinder into PostgreSQL database.
# Inserted talonflame into PostgreSQL database.
# Inserted scatterbug into PostgreSQL database.
# Inserted spewpa into PostgreSQL database.
# Inserted vivillon into PostgreSQL database.
# Inserted litleo into PostgreSQL database.
# Inserted pyroar into PostgreSQL database.
# Inserted flabebe into PostgreSQL database.
# Inserted floette into PostgreSQL database.
# Inserted florges into PostgreSQL database.
# Inserted skiddo into PostgreSQL database.
# Inserted gogoat into PostgreSQL database.
# Inserted pancham into PostgreSQL database.
# Inserted pangoro into PostgreSQL database.
# Inserted furfrou into PostgreSQL database.
# Inserted espurr into PostgreSQL database.
# Inserted meowstic-male into PostgreSQL database.
# Inserted honedge into PostgreSQL database.
# Inserted doublade into PostgreSQL database.
# Inserted aegislash-shield into PostgreSQL database.
# Inserted spritzee into PostgreSQL database.
# Inserted aromatisse into PostgreSQL database.
# Inserted swirlix into PostgreSQL database.
# Inserted slurpuff into PostgreSQL database.
# Inserted inkay into PostgreSQL database.
# Inserted malamar into PostgreSQL database.
# Inserted binacle into PostgreSQL database.
# Inserted barbaracle into PostgreSQL database.
# Inserted skrelp into PostgreSQL database.
# Inserted dragalge into PostgreSQL database.
# Inserted clauncher into PostgreSQL database.
# Inserted clawitzer into PostgreSQL database.
# Inserted helioptile into PostgreSQL database.
# Inserted heliolisk into PostgreSQL database.
# Inserted tyrunt into PostgreSQL database.
# Inserted tyrantrum into PostgreSQL database.
# Inserted amaura into PostgreSQL database.
# Inserted aurorus into PostgreSQL database.
# Inserted sylveon into PostgreSQL database.
# Inserted hawlucha into PostgreSQL database.
# Inserted dedenne into PostgreSQL database.
# Inserted carbink into PostgreSQL database.
# Inserted goomy into PostgreSQL database.
# Inserted sliggoo into PostgreSQL database.
# Inserted goodra into PostgreSQL database.
# Inserted klefki into PostgreSQL database.
# Inserted phantump into PostgreSQL database.
# Inserted trevenant into PostgreSQL database.
# Inserted pumpkaboo-average into PostgreSQL database.
# Inserted gourgeist-average into PostgreSQL database.
# Inserted bergmite into PostgreSQL database.
# Inserted avalugg into PostgreSQL database.
# Inserted noibat into PostgreSQL database.
# Inserted noivern into PostgreSQL database.
# Inserted xerneas into PostgreSQL database.
# Inserted yveltal into PostgreSQL database.
# Inserted zygarde-50 into PostgreSQL database.
# Inserted diancie into PostgreSQL database.
# Inserted hoopa into PostgreSQL database.
# Inserted volcanion into PostgreSQL database.
# Inserted rowlet into PostgreSQL database.
# Inserted dartrix into PostgreSQL database.
# Inserted decidueye into PostgreSQL database.
# Inserted litten into PostgreSQL database.
# Inserted torracat into PostgreSQL database.
# Inserted incineroar into PostgreSQL database.
# Inserted popplio into PostgreSQL database.
# Inserted brionne into PostgreSQL database.
# Inserted primarina into PostgreSQL database.
# Inserted pikipek into PostgreSQL database.
# Inserted trumbeak into PostgreSQL database.
# Inserted toucannon into PostgreSQL database.
# Inserted yungoos into PostgreSQL database.
# Inserted gumshoos into PostgreSQL database.
# Inserted grubbin into PostgreSQL database.
# Inserted charjabug into PostgreSQL database.
# Inserted vikavolt into PostgreSQL database.
# Inserted crabrawler into PostgreSQL database.
# Inserted crabominable into PostgreSQL database.
# Inserted oricorio-baile into PostgreSQL database.
# Inserted cutiefly into PostgreSQL database.
# Inserted ribombee into PostgreSQL database.
# Inserted rockruff into PostgreSQL database.
# Inserted lycanroc-midday into PostgreSQL database.
# Inserted wishiwashi-solo into PostgreSQL database.
# Inserted mareanie into PostgreSQL database.
# Inserted toxapex into PostgreSQL database.
# Inserted mudbray into PostgreSQL database.
# Inserted mudsdale into PostgreSQL database.
# Inserted dewpider into PostgreSQL database.
# Inserted araquanid into PostgreSQL database.
# Inserted fomantis into PostgreSQL database.
# Inserted lurantis into PostgreSQL database.
# Inserted morelull into PostgreSQL database.
# Inserted shiinotic into PostgreSQL database.
# Inserted salandit into PostgreSQL database.
# Inserted salazzle into PostgreSQL database.
# Inserted stufful into PostgreSQL database.
# Inserted bewear into PostgreSQL database.
# Inserted bounsweet into PostgreSQL database.
# Inserted steenee into PostgreSQL database.
# Inserted tsareena into PostgreSQL database.
# Inserted comfey into PostgreSQL database.
# Inserted oranguru into PostgreSQL database.
# Inserted passimian into PostgreSQL database.
# Inserted wimpod into PostgreSQL database.
# Inserted golisopod into PostgreSQL database.
# Inserted sandygast into PostgreSQL database.
# Inserted palossand into PostgreSQL database.
# Inserted pyukumuku into PostgreSQL database.
# Inserted type-null into PostgreSQL database.
# Inserted silvally into PostgreSQL database.
# Inserted minior-red-meteor into PostgreSQL database.
# Inserted komala into PostgreSQL database.
# Inserted turtonator into PostgreSQL database.
# Inserted togedemaru into PostgreSQL database.
# Inserted mimikyu-disguised into PostgreSQL database.
# Inserted bruxish into PostgreSQL database.
# Inserted drampa into PostgreSQL database.
# Inserted dhelmise into PostgreSQL database.
# Inserted jangmo-o into PostgreSQL database.
# Inserted hakamo-o into PostgreSQL database.
# Inserted kommo-o into PostgreSQL database.
# Inserted tapu-koko into PostgreSQL database.
# Inserted tapu-lele into PostgreSQL database.
# Inserted tapu-bulu into PostgreSQL database.
# Inserted tapu-fini into PostgreSQL database.
# Inserted cosmog into PostgreSQL database.
# Inserted cosmoem into PostgreSQL database.
# Inserted solgaleo into PostgreSQL database.
# Inserted lunala into PostgreSQL database.
# Inserted nihilego into PostgreSQL database.
# Inserted buzzwole into PostgreSQL database.
# Inserted pheromosa into PostgreSQL database.
# Inserted xurkitree into PostgreSQL database.
# Inserted celesteela into PostgreSQL database.
# Inserted kartana into PostgreSQL database.
# Inserted guzzlord into PostgreSQL database.
# Inserted necrozma into PostgreSQL database.
# Inserted magearna into PostgreSQL database.
# Inserted marshadow into PostgreSQL database.
# Inserted poipole into PostgreSQL database.
# Inserted naganadel into PostgreSQL database.
# Inserted stakataka into PostgreSQL database.
# Inserted blacephalon into PostgreSQL database.
# Inserted zeraora into PostgreSQL database.
# Inserted meltan into PostgreSQL database.
# Inserted melmetal into PostgreSQL database.
# Inserted grookey into PostgreSQL database.
# Inserted thwackey into PostgreSQL database.
# Inserted rillaboom into PostgreSQL database.
# Inserted scorbunny into PostgreSQL database.
# Inserted raboot into PostgreSQL database.
# Inserted cinderace into PostgreSQL database.
# Inserted sobble into PostgreSQL database.
# Inserted drizzile into PostgreSQL database.
# Inserted inteleon into PostgreSQL database.
# Inserted skwovet into PostgreSQL database.
# Inserted greedent into PostgreSQL database.
# Inserted rookidee into PostgreSQL database.
# Inserted corvisquire into PostgreSQL database.
# Inserted corviknight into PostgreSQL database.
# Inserted blipbug into PostgreSQL database.
# Inserted dottler into PostgreSQL database.
# Inserted orbeetle into PostgreSQL database.
# Inserted nickit into PostgreSQL database.
# Inserted thievul into PostgreSQL database.
# Inserted gossifleur into PostgreSQL database.
# Inserted eldegoss into PostgreSQL database.
# Inserted wooloo into PostgreSQL database.
# Inserted dubwool into PostgreSQL database.
# Inserted chewtle into PostgreSQL database.
# Inserted drednaw into PostgreSQL database.
# Inserted yamper into PostgreSQL database.
# Inserted boltund into PostgreSQL database.
# Inserted rolycoly into PostgreSQL database.
# Inserted carkol into PostgreSQL database.
# Inserted coalossal into PostgreSQL database.
# Inserted applin into PostgreSQL database.
# Inserted flapple into PostgreSQL database.
# Inserted appletun into PostgreSQL database.
# Inserted silicobra into PostgreSQL database.
# Inserted sandaconda into PostgreSQL database.
# Inserted cramorant into PostgreSQL database.
# Inserted arrokuda into PostgreSQL database.
# Inserted barraskewda into PostgreSQL database.
# Inserted toxel into PostgreSQL database.
# Inserted toxtricity-amped into PostgreSQL database.
# Inserted sizzlipede into PostgreSQL database.
# Inserted centiskorch into PostgreSQL database.
# Inserted clobbopus into PostgreSQL database.
# Inserted grapploct into PostgreSQL database.
# Inserted sinistea into PostgreSQL database.
# Inserted polteageist into PostgreSQL database.
# Inserted hatenna into PostgreSQL database.
# Inserted hattrem into PostgreSQL database.
# Inserted hatterene into PostgreSQL database.
# Inserted impidimp into PostgreSQL database.
# Inserted morgrem into PostgreSQL database.
# Inserted grimmsnarl into PostgreSQL database.
# Inserted obstagoon into PostgreSQL database.
# Inserted perrserker into PostgreSQL database.
# Inserted cursola into PostgreSQL database.
# Inserted sirfetchd into PostgreSQL database.
# Inserted mr-rime into PostgreSQL database.
# Inserted runerigus into PostgreSQL database.
# Inserted milcery into PostgreSQL database.
# Inserted alcremie into PostgreSQL database.
# Inserted falinks into PostgreSQL database.
# Inserted pincurchin into PostgreSQL database.
# Inserted snom into PostgreSQL database.
# Inserted frosmoth into PostgreSQL database.
# Inserted stonjourner into PostgreSQL database.
# Inserted eiscue-ice into PostgreSQL database.
# Inserted indeedee-male into PostgreSQL database.
# Inserted morpeko-full-belly into PostgreSQL database.
# Inserted cufant into PostgreSQL database.
# Inserted copperajah into PostgreSQL database.
# Inserted dracozolt into PostgreSQL database.
# Inserted arctozolt into PostgreSQL database.
# Inserted dracovish into PostgreSQL database.
# Inserted arctovish into PostgreSQL database.
# Inserted duraludon into PostgreSQL database.
# Inserted dreepy into PostgreSQL database.
# Inserted drakloak into PostgreSQL database.
# Inserted dragapult into PostgreSQL database.
# Inserted zacian into PostgreSQL database.
# Inserted zamazenta into PostgreSQL database.
# Inserted eternatus into PostgreSQL database.
# Inserted kubfu into PostgreSQL database.
# Inserted urshifu-single-strike into PostgreSQL database.
# Inserted zarude into PostgreSQL database.
# Inserted regieleki into PostgreSQL database.
# Inserted regidrago into PostgreSQL database.
# Inserted glastrier into PostgreSQL database.
# Inserted spectrier into PostgreSQL database.
# Inserted calyrex into PostgreSQL database.
# Inserted wyrdeer into PostgreSQL database.
# Inserted kleavor into PostgreSQL database.
# Inserted ursaluna into PostgreSQL database.
# Inserted basculegion-male into PostgreSQL database.
# Inserted sneasler into PostgreSQL database.
# Inserted overqwil into PostgreSQL database.
# Inserted enamorus-incarnate into PostgreSQL database.
# Inserted sprigatito into PostgreSQL database.
# Inserted floragato into PostgreSQL database.
# Inserted meowscarada into PostgreSQL database.
# Inserted fuecoco into PostgreSQL database.
# Inserted crocalor into PostgreSQL database.
# Inserted skeledirge into PostgreSQL database.
# Inserted quaxly into PostgreSQL database.
# Inserted quaxwell into PostgreSQL database.
# Inserted quaquaval into PostgreSQL database.
# Inserted lechonk into PostgreSQL database.
# Inserted oinkologne-male into PostgreSQL database.
# Inserted tarountula into PostgreSQL database.
# Inserted spidops into PostgreSQL database.
# Inserted nymble into PostgreSQL database.
# Inserted lokix into PostgreSQL database.
# Inserted pawmi into PostgreSQL database.
# Inserted pawmo into PostgreSQL database.
# Inserted pawmot into PostgreSQL database.
# Inserted tandemaus into PostgreSQL database.
# Inserted maushold-family-of-four into PostgreSQL database.
# Inserted fidough into PostgreSQL database.
# Inserted dachsbun into PostgreSQL database.
# Inserted smoliv into PostgreSQL database.
# Inserted dolliv into PostgreSQL database.
# Inserted arboliva into PostgreSQL database.
# Inserted squawkabilly-green-plumage into PostgreSQL database.
# Inserted nacli into PostgreSQL database.
# Inserted naclstack into PostgreSQL database.
# Inserted garganacl into PostgreSQL database.
# Inserted charcadet into PostgreSQL database.
# Inserted armarouge into PostgreSQL database.
# Inserted ceruledge into PostgreSQL database.
# Inserted tadbulb into PostgreSQL database.
# Inserted bellibolt into PostgreSQL database.
# Inserted wattrel into PostgreSQL database.
# Inserted kilowattrel into PostgreSQL database.
# Inserted maschiff into PostgreSQL database.
# Inserted mabosstiff into PostgreSQL database.
# Inserted shroodle into PostgreSQL database.
# Inserted grafaiai into PostgreSQL database.
# Inserted bramblin into PostgreSQL database.
# Inserted brambleghast into PostgreSQL database.
# Inserted toedscool into PostgreSQL database.
# Inserted toedscruel into PostgreSQL database.
# Inserted klawf into PostgreSQL database.
# Inserted capsakid into PostgreSQL database.
# Inserted scovillain into PostgreSQL database.
# Inserted rellor into PostgreSQL database.
# Inserted rabsca into PostgreSQL database.
# Inserted flittle into PostgreSQL database.
# Inserted espathra into PostgreSQL database.
# Inserted tinkatink into PostgreSQL database.
# Inserted tinkatuff into PostgreSQL database.
# Inserted tinkaton into PostgreSQL database.
# Inserted wiglett into PostgreSQL database.
# Inserted wugtrio into PostgreSQL database.
# Inserted bombirdier into PostgreSQL database.
# Inserted finizen into PostgreSQL database.
# Inserted palafin-zero into PostgreSQL database.
# Inserted varoom into PostgreSQL database.
# Inserted revavroom into PostgreSQL database.
# Inserted cyclizar into PostgreSQL database.
# Inserted orthworm into PostgreSQL database.
# Inserted glimmet into PostgreSQL database.
# Inserted glimmora into PostgreSQL database.
# Inserted greavard into PostgreSQL database.
# Inserted houndstone into PostgreSQL database.
# Inserted flamigo into PostgreSQL database.
# Inserted cetoddle into PostgreSQL database.
# Inserted cetitan into PostgreSQL database.
# Inserted veluza into PostgreSQL database.
# Inserted dondozo into PostgreSQL database.
# Inserted tatsugiri-curly into PostgreSQL database.
# Inserted annihilape into PostgreSQL database.
# Inserted clodsire into PostgreSQL database.
# Inserted farigiraf into PostgreSQL database.
# Inserted dudunsparce-two-segment into PostgreSQL database.
# Inserted kingambit into PostgreSQL database.
# Inserted great-tusk into PostgreSQL database.
# Inserted scream-tail into PostgreSQL database.
# Inserted brute-bonnet into PostgreSQL database.
# Inserted flutter-mane into PostgreSQL database.
# Inserted slither-wing into PostgreSQL database.
# Inserted sandy-shocks into PostgreSQL database.
# Inserted iron-treads into PostgreSQL database.
# Inserted iron-bundle into PostgreSQL database.
# Inserted iron-hands into PostgreSQL database.
# Inserted iron-jugulis into PostgreSQL database.
# Inserted iron-moth into PostgreSQL database.
# Inserted iron-thorns into PostgreSQL database.
# Inserted frigibax into PostgreSQL database.
# Inserted arctibax into PostgreSQL database.
# Inserted baxcalibur into PostgreSQL database.
# Inserted gimmighoul into PostgreSQL database.
# Inserted gholdengo into PostgreSQL database.
# Inserted wo-chien into PostgreSQL database.
# Inserted chien-pao into PostgreSQL database.
# Inserted ting-lu into PostgreSQL database.
# Inserted chi-yu into PostgreSQL database.
# Inserted roaring-moon into PostgreSQL database.
# Inserted iron-valiant into PostgreSQL database.
# Inserted koraidon into PostgreSQL database.
# Inserted miraidon into PostgreSQL database.
# Inserted walking-wake into PostgreSQL database.
# Inserted iron-leaves into PostgreSQL database.
# Inserted dipplin into PostgreSQL database.
# Inserted poltchageist into PostgreSQL database.
# Inserted sinistcha into PostgreSQL database.
# Inserted okidogi into PostgreSQL database.
# Inserted munkidori into PostgreSQL database.
# Inserted fezandipiti into PostgreSQL database.
# Inserted ogerpon into PostgreSQL database.
# Inserted archaludon into PostgreSQL database.
# Inserted hydrapple into PostgreSQL database.
# Inserted gouging-fire into PostgreSQL database.
# Inserted raging-bolt into PostgreSQL database.
# Inserted iron-boulder into PostgreSQL database.
# Inserted iron-crown into PostgreSQL database.
# Inserted terapagos into PostgreSQL database.
# Inserted pecharunt into PostgreSQL database.
# Inserted deoxys-attack into PostgreSQL database.
# Inserted deoxys-defense into PostgreSQL database.
# Inserted deoxys-speed into PostgreSQL database.
# Inserted wormadam-sandy into PostgreSQL database.
# Inserted wormadam-trash into PostgreSQL database.
# Inserted shaymin-sky into PostgreSQL database.
# Inserted giratina-origin into PostgreSQL database.
# Inserted rotom-heat into PostgreSQL database.
# Inserted rotom-wash into PostgreSQL database.
# Inserted rotom-frost into PostgreSQL database.
# Inserted rotom-fan into PostgreSQL database.
# Inserted rotom-mow into PostgreSQL database.
# Inserted castform-sunny into PostgreSQL database.
# Inserted castform-rainy into PostgreSQL database.
# Inserted castform-snowy into PostgreSQL database.
# Inserted basculin-blue-striped into PostgreSQL database.
# Inserted darmanitan-zen into PostgreSQL database.
# Inserted meloetta-pirouette into PostgreSQL database.
# Inserted tornadus-therian into PostgreSQL database.
# Inserted thundurus-therian into PostgreSQL database.
# Inserted landorus-therian into PostgreSQL database.
# Inserted kyurem-black into PostgreSQL database.
# Inserted kyurem-white into PostgreSQL database.
# Inserted keldeo-resolute into PostgreSQL database.
# Inserted meowstic-female into PostgreSQL database.
# Inserted aegislash-blade into PostgreSQL database.
# Inserted pumpkaboo-small into PostgreSQL database.
# Inserted pumpkaboo-large into PostgreSQL database.
# Inserted pumpkaboo-super into PostgreSQL database.
# Inserted gourgeist-small into PostgreSQL database.
# Inserted gourgeist-large into PostgreSQL database.
# Inserted gourgeist-super into PostgreSQL database.
# Inserted venusaur-mega into PostgreSQL database.
# Inserted charizard-mega-x into PostgreSQL database.
# Inserted charizard-mega-y into PostgreSQL database.
# Inserted blastoise-mega into PostgreSQL database.
# Inserted alakazam-mega into PostgreSQL database.
# Inserted gengar-mega into PostgreSQL database.
# Inserted kangaskhan-mega into PostgreSQL database.
# Inserted pinsir-mega into PostgreSQL database.
# Inserted gyarados-mega into PostgreSQL database.
# Inserted aerodactyl-mega into PostgreSQL database.
# Inserted mewtwo-mega-x into PostgreSQL database.
# Inserted mewtwo-mega-y into PostgreSQL database.
# Inserted ampharos-mega into PostgreSQL database.
# Inserted scizor-mega into PostgreSQL database.
# Inserted heracross-mega into PostgreSQL database.
# Inserted houndoom-mega into PostgreSQL database.
# Inserted tyranitar-mega into PostgreSQL database.
# Inserted blaziken-mega into PostgreSQL database.
# Inserted gardevoir-mega into PostgreSQL database.
# Inserted mawile-mega into PostgreSQL database.
# Inserted aggron-mega into PostgreSQL database.
# Inserted medicham-mega into PostgreSQL database.
# Inserted manectric-mega into PostgreSQL database.
# Inserted banette-mega into PostgreSQL database.
# Inserted absol-mega into PostgreSQL database.
# Inserted garchomp-mega into PostgreSQL database.
# Inserted lucario-mega into PostgreSQL database.
# Inserted abomasnow-mega into PostgreSQL database.
# Inserted floette-eternal into PostgreSQL database.
# Inserted latias-mega into PostgreSQL database.
# Inserted latios-mega into PostgreSQL database.
# Inserted swampert-mega into PostgreSQL database.
# Inserted sceptile-mega into PostgreSQL database.
# Inserted sableye-mega into PostgreSQL database.
# Inserted altaria-mega into PostgreSQL database.
# Inserted gallade-mega into PostgreSQL database.
# Inserted audino-mega into PostgreSQL database.
# Inserted sharpedo-mega into PostgreSQL database.
# Inserted slowbro-mega into PostgreSQL database.
# Inserted steelix-mega into PostgreSQL database.
# Inserted pidgeot-mega into PostgreSQL database.
# Inserted glalie-mega into PostgreSQL database.
# Inserted diancie-mega into PostgreSQL database.
# Inserted metagross-mega into PostgreSQL database.
# Inserted kyogre-primal into PostgreSQL database.
# Inserted groudon-primal into PostgreSQL database.
# Inserted rayquaza-mega into PostgreSQL database.
# Inserted pikachu-rock-star into PostgreSQL database.
# Inserted pikachu-belle into PostgreSQL database.
# Inserted pikachu-pop-star into PostgreSQL database.
# Inserted pikachu-phd into PostgreSQL database.
# Inserted pikachu-libre into PostgreSQL database.
# Inserted pikachu-cosplay into PostgreSQL database.
# Inserted hoopa-unbound into PostgreSQL database.
# Inserted camerupt-mega into PostgreSQL database.
# Inserted lopunny-mega into PostgreSQL database.
# Inserted salamence-mega into PostgreSQL database.
# Inserted beedrill-mega into PostgreSQL database.
# Inserted rattata-alola into PostgreSQL database.
# Inserted raticate-alola into PostgreSQL database.
# Inserted raticate-totem-alola into PostgreSQL database.
# Inserted pikachu-original-cap into PostgreSQL database.
# Inserted pikachu-hoenn-cap into PostgreSQL database.
# Inserted pikachu-sinnoh-cap into PostgreSQL database.
# Inserted pikachu-unova-cap into PostgreSQL database.
# Inserted pikachu-kalos-cap into PostgreSQL database.
# Inserted pikachu-alola-cap into PostgreSQL database.
# Inserted raichu-alola into PostgreSQL database.
# Inserted sandshrew-alola into PostgreSQL database.
# Inserted sandslash-alola into PostgreSQL database.
# Inserted vulpix-alola into PostgreSQL database.
# Inserted ninetales-alola into PostgreSQL database.
# Inserted diglett-alola into PostgreSQL database.
# Inserted dugtrio-alola into PostgreSQL database.
# Inserted meowth-alola into PostgreSQL database.
# Inserted persian-alola into PostgreSQL database.
# Inserted geodude-alola into PostgreSQL database.
# Inserted graveler-alola into PostgreSQL database.
# Inserted golem-alola into PostgreSQL database.
# Inserted grimer-alola into PostgreSQL database.
# Inserted muk-alola into PostgreSQL database.
# Inserted exeggutor-alola into PostgreSQL database.
# Inserted marowak-alola into PostgreSQL database.
# Inserted greninja-battle-bond into PostgreSQL database.
# Inserted greninja-ash into PostgreSQL database.
# Inserted zygarde-10-power-construct into PostgreSQL database.
# Inserted zygarde-50-power-construct into PostgreSQL database.
# Inserted zygarde-complete into PostgreSQL database.
# Inserted gumshoos-totem into PostgreSQL database.
# Inserted vikavolt-totem into PostgreSQL database.
# Inserted oricorio-pom-pom into PostgreSQL database.
# Inserted oricorio-pau into PostgreSQL database.
# Inserted oricorio-sensu into PostgreSQL database.
# Inserted lycanroc-midnight into PostgreSQL database.
# Inserted wishiwashi-school into PostgreSQL database.
# Inserted lurantis-totem into PostgreSQL database.
# Inserted salazzle-totem into PostgreSQL database.
# Inserted minior-orange-meteor into PostgreSQL database.
# Inserted minior-yellow-meteor into PostgreSQL database.
# Inserted minior-green-meteor into PostgreSQL database.
# Inserted minior-blue-meteor into PostgreSQL database.
# Inserted minior-indigo-meteor into PostgreSQL database.
# Inserted minior-violet-meteor into PostgreSQL database.
# Inserted minior-red into PostgreSQL database.
# Inserted minior-orange into PostgreSQL database.
# Inserted minior-yellow into PostgreSQL database.
# Inserted minior-green into PostgreSQL database.
# Inserted minior-blue into PostgreSQL database.
# Inserted minior-indigo into PostgreSQL database.
# Inserted minior-violet into PostgreSQL database.
# Inserted mimikyu-busted into PostgreSQL database.
# Inserted mimikyu-totem-disguised into PostgreSQL database.
# Inserted mimikyu-totem-busted into PostgreSQL database.
# Inserted kommo-o-totem into PostgreSQL database.
# Inserted magearna-original into PostgreSQL database.
# Inserted pikachu-partner-cap into PostgreSQL database.
# Inserted marowak-totem into PostgreSQL database.
# Inserted ribombee-totem into PostgreSQL database.
# Inserted rockruff-own-tempo into PostgreSQL database.
# Inserted lycanroc-dusk into PostgreSQL database.
# Inserted araquanid-totem into PostgreSQL database.
# Inserted togedemaru-totem into PostgreSQL database.
# Inserted necrozma-dusk into PostgreSQL database.
# Inserted necrozma-dawn into PostgreSQL database.
# Inserted necrozma-ultra into PostgreSQL database.
# Inserted pikachu-starter into PostgreSQL database.
# Inserted eevee-starter into PostgreSQL database.
# Inserted pikachu-world-cap into PostgreSQL database.
# Inserted meowth-galar into PostgreSQL database.
# Inserted ponyta-galar into PostgreSQL database.
# Inserted rapidash-galar into PostgreSQL database.
# Inserted slowpoke-galar into PostgreSQL database.
# Inserted slowbro-galar into PostgreSQL database.
# Inserted farfetchd-galar into PostgreSQL database.
# Inserted weezing-galar into PostgreSQL database.
# Inserted mr-mime-galar into PostgreSQL database.
# Inserted articuno-galar into PostgreSQL database.
# Inserted zapdos-galar into PostgreSQL database.
# Inserted moltres-galar into PostgreSQL database.
# Inserted slowking-galar into PostgreSQL database.
# Inserted corsola-galar into PostgreSQL database.
# Inserted zigzagoon-galar into PostgreSQL database.
# Inserted linoone-galar into PostgreSQL database.
# Inserted darumaka-galar into PostgreSQL database.
# Inserted darmanitan-galar-standard into PostgreSQL database.
# Inserted darmanitan-galar-zen into PostgreSQL database.
# Inserted yamask-galar into PostgreSQL database.
# Inserted stunfisk-galar into PostgreSQL database.
# Inserted zygarde-10 into PostgreSQL database.
# Inserted cramorant-gulping into PostgreSQL database.
# Inserted cramorant-gorging into PostgreSQL database.
# Inserted toxtricity-low-key into PostgreSQL database.
# Inserted eiscue-noice into PostgreSQL database.
# Inserted indeedee-female into PostgreSQL database.
# Inserted morpeko-hangry into PostgreSQL database.
# Inserted zacian-crowned into PostgreSQL database.
# Inserted zamazenta-crowned into PostgreSQL database.
# Inserted eternatus-eternamax into PostgreSQL database.
# Inserted urshifu-rapid-strike into PostgreSQL database.
# Inserted zarude-dada into PostgreSQL database.
# Inserted calyrex-ice into PostgreSQL database.
# Inserted calyrex-shadow into PostgreSQL database.
# Inserted venusaur-gmax into PostgreSQL database.
# Inserted charizard-gmax into PostgreSQL database.
# Inserted blastoise-gmax into PostgreSQL database.
# Inserted butterfree-gmax into PostgreSQL database.
# Inserted pikachu-gmax into PostgreSQL database.
# Inserted meowth-gmax into PostgreSQL database.
# Inserted machamp-gmax into PostgreSQL database.
# Inserted gengar-gmax into PostgreSQL database.
# Inserted kingler-gmax into PostgreSQL database.
# Inserted lapras-gmax into PostgreSQL database.
# Inserted eevee-gmax into PostgreSQL database.
# Inserted snorlax-gmax into PostgreSQL database.
# Inserted garbodor-gmax into PostgreSQL database.
# Inserted melmetal-gmax into PostgreSQL database.
# Inserted rillaboom-gmax into PostgreSQL database.
# Inserted cinderace-gmax into PostgreSQL database.
# Inserted inteleon-gmax into PostgreSQL database.
# Inserted corviknight-gmax into PostgreSQL database.
# Inserted orbeetle-gmax into PostgreSQL database.
# Inserted drednaw-gmax into PostgreSQL database.
# Inserted coalossal-gmax into PostgreSQL database.
# Inserted flapple-gmax into PostgreSQL database.
# Inserted appletun-gmax into PostgreSQL database.
# Inserted sandaconda-gmax into PostgreSQL database.
# Inserted toxtricity-amped-gmax into PostgreSQL database.
# Inserted centiskorch-gmax into PostgreSQL database.
# Inserted hatterene-gmax into PostgreSQL database.
# Inserted grimmsnarl-gmax into PostgreSQL database.
# Inserted alcremie-gmax into PostgreSQL database.
# Inserted copperajah-gmax into PostgreSQL database.
# Inserted duraludon-gmax into PostgreSQL database.
# Inserted urshifu-single-strike-gmax into PostgreSQL database.
# Inserted urshifu-rapid-strike-gmax into PostgreSQL database.
# Inserted toxtricity-low-key-gmax into PostgreSQL database.
# Inserted growlithe-hisui into PostgreSQL database.
# Inserted arcanine-hisui into PostgreSQL database.
# Inserted voltorb-hisui into PostgreSQL database.
# Inserted electrode-hisui into PostgreSQL database.
# Inserted typhlosion-hisui into PostgreSQL database.
# Inserted qwilfish-hisui into PostgreSQL database.
# Inserted sneasel-hisui into PostgreSQL database.
# Inserted samurott-hisui into PostgreSQL database.
# Inserted lilligant-hisui into PostgreSQL database.
# Inserted zorua-hisui into PostgreSQL database.
# Inserted zoroark-hisui into PostgreSQL database.
# Inserted braviary-hisui into PostgreSQL database.
# Inserted sliggoo-hisui into PostgreSQL database.
# Inserted goodra-hisui into PostgreSQL database.
# Inserted avalugg-hisui into PostgreSQL database.
# Inserted decidueye-hisui into PostgreSQL database.
# Inserted dialga-origin into PostgreSQL database.
# Inserted palkia-origin into PostgreSQL database.
# Inserted basculin-white-striped into PostgreSQL database.
# Inserted basculegion-female into PostgreSQL database.
# Inserted enamorus-therian into PostgreSQL database.
# Inserted tauros-paldea-combat-breed into PostgreSQL database.
# Inserted tauros-paldea-blaze-breed into PostgreSQL database.
# Inserted tauros-paldea-aqua-breed into PostgreSQL database.
# Inserted wooper-paldea into PostgreSQL database.
# Inserted oinkologne-female into PostgreSQL database.
# Inserted dudunsparce-three-segment into PostgreSQL database.
# Inserted palafin-hero into PostgreSQL database.
# Inserted maushold-family-of-three into PostgreSQL database.
# Inserted tatsugiri-droopy into PostgreSQL database.
# Inserted tatsugiri-stretchy into PostgreSQL database.
# Inserted squawkabilly-blue-plumage into PostgreSQL database.
# Inserted squawkabilly-yellow-plumage into PostgreSQL database.
# Inserted squawkabilly-white-plumage into PostgreSQL database.
# Inserted gimmighoul-roaming into PostgreSQL database.
# Inserted koraidon-limited-build into PostgreSQL database.
# Inserted koraidon-sprinting-build into PostgreSQL database.
# Inserted koraidon-swimming-build into PostgreSQL database.
# Inserted koraidon-gliding-build into PostgreSQL database.
# Inserted miraidon-low-power-mode into PostgreSQL database.
# Inserted miraidon-drive-mode into PostgreSQL database.
# Inserted miraidon-aquatic-mode into PostgreSQL database.
# Inserted miraidon-glide-mode into PostgreSQL database.
# Inserted ursaluna-bloodmoon into PostgreSQL database.
# Inserted ogerpon-wellspring-mask into PostgreSQL database.
# Inserted ogerpon-hearthflame-mask into PostgreSQL database.
# Inserted ogerpon-cornerstone-mask into PostgreSQL database.
# Inserted terapagos-terastal into PostgreSQL database.
# Inserted terapagos-stellar into PostgreSQL database.

# %%
def get_pokemon():
    """Fetch all Pokémon from the database."""
    conn = connect_db()
    cursor = conn.cursor()
    
    cursor.execute("SELECT * FROM pokemon")
    results = cursor.fetchall()
    
    for row in results:
        print(row)
    
    cursor.close()
    conn.close()

get_pokemon()
# Out:
# (25, 'pikachu', 4, 60, 112)
# (4, 'charmander', 6, 85, 62)
# (1, 'bulbasaur', 7, 69, 64)
# (7, 'squirtle', 5, 90, 63)
